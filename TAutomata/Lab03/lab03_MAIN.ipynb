# %% [markdown]
# # Task

# %% [markdown]
# ## Задание  1
# Установить gym (python3 - https://github.com/openai/gym, для тех, кто делает на java - https://github.com/deeplearning4j/gym-java-client), реализовать среду из предыдущего семинара в gym, агенты - тигр и кролик. Реализовать задачу из семинара 2 в openai gym.

# %% [markdown]
# ## Задание  2
# Реализовать поведение "поиска" добычи тигром - тигр исследует карту и выслеживает добычу (оказывается в 3 клетках от нее - добыча выслежена). Далее он следует к добыче и пытается ее поймать (как на 1 семинаре). Если кролик уворачивается от тигра, то он отбегает на 5 клеток в любом направлении. Каждый раз, после неудачной ловли, тигр усовершенствует свой уровень охотника на 10 %. Для обеспечения поиска добычи использовать DQN.

# %%
SEED = 42

# %% [markdown]
# # Location

# %%
import numpy as np


class Location:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def toNumpy(self):
        return np.array([self.y, self.x], dtype=int)

    def dist(self, other):
        return np.linalg.norm(self.toNumpy() - other.toNumpy(), ord=1)
    
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    
    def __lt__(self, other):
        return self.x < other.x and self.y < other.y
    
    def __repr__(self):
        return '(' + str(self.x) + ', ' + str(self.y) + ')'

# %% [markdown]
# # Gym

# %% [markdown]
# ## Agent

# %%
from pandas.core.arrays.sparse import dtype
class Agent:
    def __init__(self, size):
        self.area_size = size
        self.location = Location(0, 0)
        self.purpose = 0
        self.attack = 0.1
    
    def reset(self):
        self.location = Location(0, 0)
        self.purpose = 0
        self.attack = 0.1

    def get_state(self):
        state = self.location.toNumpy()
        state = np.append(state, [self.purpose]).astype(int)
        return state

# %% [markdown]
# ## Target

# %%
class Target:
    def __init__(self, size, x=None, y=None, n_routes=100, escape=np.random.random()):
        self.area_size = size
        self.backup = {'location': None, 'route': None}
        self.location = self.create_location(x, y, size)
        self.route = self.create_escape_route(n_routes)
        self.escape = escape
        
    
    def create_location(self, x, y, size):
        x = x if x is not None else np.random.randint(size)
        y = y if y is not None else np.random.randint(size)
        while x == 0 and y == 0:
            x = np.random.randint(size)
            y = np.random.randint(size)
        self.backup['location'] = Location(x, y)
        return Location(x, y)
    
    
    def create_escape_route(self, n):
        area = self.area_size
        loc = self.location
        x, y = loc.x, loc.y
        route = []
        for i in range(n):   
            dx = np.random.randint(-5, 5)
            dy = 5 - abs(dx) if np.random.uniform(0, 1) < 0.5 else abs(dx) - 5
            new_x = x + dx
            new_y = y + dy
            while not (0 <= new_x < area and 0 <= new_y < area):
                dx = np.random.randint(-5, 5)
                dy = 5 - abs(dx) if np.random.uniform(0, 1) < 0.5 else abs(dx) - 5
                new_x = x + dx
                new_y = y + dy
            route.append(Location(new_x, new_y))
            x = new_x
            y = new_y
        self.backup['route'] = list(route)
        return route


    def run(self):
        self.location = self.route.pop(0)

    def reset(self):
        self.location = Location(self.backup['location'].x, self.backup['location'].y)
        self.route = list(self.backup['route'])

    def get_state(self):
        return self.location.toNumpy()

    def update(self):
        self.location = Location(0, 0)

# %% [markdown]
# ## Enviroment

# %%
import gym
from gym import spaces
import pandas as pd
from IPython.display import display
from IPython.display import clear_output


class HunterWorldEnv(gym.Env):

    metadata = {"render_modes": ["human", "network"]}

    def __init__(self, agent, target, size=10, render_mode='human'):
        self.size = size
        self.agent = agent
        self.target = target
        self.render_mode = render_mode
        self.observation_space = spaces.Dict(
            {
                "agent": spaces.Box(0, np.array([size - 1, size - 1, 1]), dtype=int),
                "target": spaces.Box(0, size - 1, shape=(2,), dtype=int),
            }
        ) 
        self.action_space = spaces.Discrete(5)
        self._action_to_direction = {
            0: np.array([1, 0]),
            1: np.array([0, 1]),
            2: np.array([-1, 0]),
            3: np.array([0, -1]),
        }
        
    def _get_obs(self):
        agent = self.agent.get_state()
        target = self.target.get_state()
        return {"agent": agent,
                "target": target,
                "state": np.concatenate([agent, target])}

    def _get_info(self):
        return {"distance": self.agent.location.dist(self.target.location)}

    def reset(self):
        super().reset(seed=SEED)
        self.agent.reset()
        self.target.reset()
        observation = self._get_obs()
        info = self._get_info()
        return observation, info

    def step(self, action):
        if action == 4:
            if self.agent.location == self.target.location and self.agent.purpose == 0:
                if self.agent.attack > self.target.escape:
                    self.agent.purpose = 1
                    self.target.update()
                    return self._get_obs(), 1000, False, self._get_info()
                self.agent.attack += 0.1
                self.target.run()
                return self._get_obs(), 1000, False, self._get_info()
            return self._get_obs(), -500, False, self._get_info()
                  
        direction = self._action_to_direction[action]
        new_loc = np.clip(self.agent.location.toNumpy() + direction, 0, self.size - 1)
        self.agent.location = Location(new_loc[1], new_loc[0])
        
        observation = self._get_obs()
        info = self._get_info()
        reward = -info['distance']

        if self.agent.location == self.target.location and self.agent.purpose == 1:
            return observation, 1000, True, info

        return observation, reward, False, info

    def render(self):
        if self.render_mode == 'human':
            return self.render_human()
        return self.render_network()

    def render_human(self):
        clear_output(wait=True)

        def cell_color(val):
            color = 'white'
            if val == 'A':
                color = 'blue'
            if val == 'T':
                color = 'green'
            if val == 'X':
                color = 'red'
            if val == 'O':
                color = 'yellow'
            return 'color: %s' % color
        
        n = self.size
        desk = np.full((n, n), '.').astype(str)
        desk[self.agent.location.y, self.agent.location.x] = 'A'
        desk[self.target.location.y, self.target.location.x] = 'T' if self.agent.purpose == 0 \
                                                                 else 'O'
        if self.agent.location == self.target.location and self.agent.purpose == 0:
            desk[self.agent.location.y, self.agent.location.x] = 'X'
        display(pd.DataFrame(desk).style.applymap(cell_color))

    def render_network(self):        
        n = self.size
        desk = np.full((n, n), 0).astype(int)
        desk[self.agent.location.y, self.agent.location.x] = 1
        desk[self.target.location.y, self.target.location.x] = 2 if self.agent.purpose == 0 \
                                                                 else 3
        if self.agent.location == self.target.location and self.agent.purpose == 0:
            desk[self.agent.location.y, self.agent.location.x] = 4
        return desk.reshape(1, n, n)

# %% [markdown]
# # Q-table

# %% [markdown]
# ## Table Agent

# %%
class TableAgent(Agent):
    def __init__(self, size):
        super().__init__(size)
        self.q_table = np.zeros((size, size, 2, size, size, 5))
        self.alpha = 0.1
        self.gamma = 0.6
        self.epsilon = 0.2

    def get_action(self, state, epsilon=-1):
        if np.random.uniform(0, 1) < epsilon:
            return np.random.randint(5)
        return np.argmax(self.q_table[state[0], state[1], state[2], 
                                      state[3], state[4]])

    def update(self, state, action, reward, next_state):
        old_value = self.q_table[state[0], state[1], state[2], state[3], 
                                 state[4], action]
        next_max = np.max(self.q_table[next_state[0], next_state[1], next_state[2], 
                                       next_state[3], next_state[4]])
        new_value = (1 - self.alpha) * old_value + self.alpha * (reward + self.gamma * next_max)
        self.q_table[state[0], state[1], state[2], state[3], state[4], action] = new_value

# %% [markdown]
# ## Init

# %%
np.random.seed = SEED

size = 10
agent = TableAgent(size)
target = Target(size)
env = HunterWorldEnv(agent, target, size)
env.render()
# Out:
# <style type="text/css">
# #T_ea045_row0_col0 {
#   color: blue;
# }
# #T_ea045_row0_col1, #T_ea045_row0_col2, #T_ea045_row0_col3, #T_ea045_row0_col4, #T_ea045_row0_col5, #T_ea045_row0_col6, #T_ea045_row0_col7, #T_ea045_row0_col8, #T_ea045_row0_col9, #T_ea045_row1_col0, #T_ea045_row1_col2, #T_ea045_row1_col3, #T_ea045_row1_col4, #T_ea045_row1_col5, #T_ea045_row1_col6, #T_ea045_row1_col7, #T_ea045_row1_col8, #T_ea045_row1_col9, #T_ea045_row2_col0, #T_ea045_row2_col1, #T_ea045_row2_col2, #T_ea045_row2_col3, #T_ea045_row2_col4, #T_ea045_row2_col5, #T_ea045_row2_col6, #T_ea045_row2_col7, #T_ea045_row2_col8, #T_ea045_row2_col9, #T_ea045_row3_col0, #T_ea045_row3_col1, #T_ea045_row3_col2, #T_ea045_row3_col3, #T_ea045_row3_col4, #T_ea045_row3_col5, #T_ea045_row3_col6, #T_ea045_row3_col7, #T_ea045_row3_col8, #T_ea045_row3_col9, #T_ea045_row4_col0, #T_ea045_row4_col1, #T_ea045_row4_col2, #T_ea045_row4_col3, #T_ea045_row4_col4, #T_ea045_row4_col5, #T_ea045_row4_col6, #T_ea045_row4_col7, #T_ea045_row4_col8, #T_ea045_row4_col9, #T_ea045_row5_col0, #T_ea045_row5_col1, #T_ea045_row5_col2, #T_ea045_row5_col3, #T_ea045_row5_col4, #T_ea045_row5_col5, #T_ea045_row5_col6, #T_ea045_row5_col7, #T_ea045_row5_col8, #T_ea045_row5_col9, #T_ea045_row6_col0, #T_ea045_row6_col1, #T_ea045_row6_col2, #T_ea045_row6_col3, #T_ea045_row6_col4, #T_ea045_row6_col5, #T_ea045_row6_col6, #T_ea045_row6_col7, #T_ea045_row6_col8, #T_ea045_row6_col9, #T_ea045_row7_col0, #T_ea045_row7_col1, #T_ea045_row7_col2, #T_ea045_row7_col3, #T_ea045_row7_col4, #T_ea045_row7_col5, #T_ea045_row7_col6, #T_ea045_row7_col7, #T_ea045_row7_col8, #T_ea045_row7_col9, #T_ea045_row8_col0, #T_ea045_row8_col1, #T_ea045_row8_col2, #T_ea045_row8_col3, #T_ea045_row8_col4, #T_ea045_row8_col5, #T_ea045_row8_col6, #T_ea045_row8_col7, #T_ea045_row8_col8, #T_ea045_row8_col9, #T_ea045_row9_col0, #T_ea045_row9_col1, #T_ea045_row9_col2, #T_ea045_row9_col3, #T_ea045_row9_col4, #T_ea045_row9_col5, #T_ea045_row9_col6, #T_ea045_row9_col7, #T_ea045_row9_col8, #T_ea045_row9_col9 {
#   color: white;
# }
# #T_ea045_row1_col1 {
#   color: green;
# }
# </style>
# <table id="T_ea045_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea045_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea045_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_ea045_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_ea045_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_ea045_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_ea045_row0_col4" class="data row0 col4" >.</td>
#       <td id="T_ea045_row0_col5" class="data row0 col5" >.</td>
#       <td id="T_ea045_row0_col6" class="data row0 col6" >.</td>
#       <td id="T_ea045_row0_col7" class="data row0 col7" >.</td>
#       <td id="T_ea045_row0_col8" class="data row0 col8" >.</td>
#       <td id="T_ea045_row0_col9" class="data row0 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_ea045_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea045_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_ea045_row1_col1" class="data row1 col1" >T</td>
#       <td id="T_ea045_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_ea045_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_ea045_row1_col4" class="data row1 col4" >.</td>
#       <td id="T_ea045_row1_col5" class="data row1 col5" >.</td>
#       <td id="T_ea045_row1_col6" class="data row1 col6" >.</td>
#       <td id="T_ea045_row1_col7" class="data row1 col7" >.</td>
#       <td id="T_ea045_row1_col8" class="data row1 col8" >.</td>
#       <td id="T_ea045_row1_col9" class="data row1 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_ea045_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea045_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_ea045_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_ea045_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_ea045_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_ea045_row2_col4" class="data row2 col4" >.</td>
#       <td id="T_ea045_row2_col5" class="data row2 col5" >.</td>
#       <td id="T_ea045_row2_col6" class="data row2 col6" >.</td>
#       <td id="T_ea045_row2_col7" class="data row2 col7" >.</td>
#       <td id="T_ea045_row2_col8" class="data row2 col8" >.</td>
#       <td id="T_ea045_row2_col9" class="data row2 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_ea045_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea045_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_ea045_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_ea045_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_ea045_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_ea045_row3_col4" class="data row3 col4" >.</td>
#       <td id="T_ea045_row3_col5" class="data row3 col5" >.</td>
#       <td id="T_ea045_row3_col6" class="data row3 col6" >.</td>
#       <td id="T_ea045_row3_col7" class="data row3 col7" >.</td>
#       <td id="T_ea045_row3_col8" class="data row3 col8" >.</td>
#       <td id="T_ea045_row3_col9" class="data row3 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_ea045_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ea045_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_ea045_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_ea045_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_ea045_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_ea045_row4_col4" class="data row4 col4" >.</td>
#       <td id="T_ea045_row4_col5" class="data row4 col5" >.</td>
#       <td id="T_ea045_row4_col6" class="data row4 col6" >.</td>
#       <td id="T_ea045_row4_col7" class="data row4 col7" >.</td>
#       <td id="T_ea045_row4_col8" class="data row4 col8" >.</td>
#       <td id="T_ea045_row4_col9" class="data row4 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_ea045_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ea045_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_ea045_row5_col1" class="data row5 col1" >.</td>
#       <td id="T_ea045_row5_col2" class="data row5 col2" >.</td>
#       <td id="T_ea045_row5_col3" class="data row5 col3" >.</td>
#       <td id="T_ea045_row5_col4" class="data row5 col4" >.</td>
#       <td id="T_ea045_row5_col5" class="data row5 col5" >.</td>
#       <td id="T_ea045_row5_col6" class="data row5 col6" >.</td>
#       <td id="T_ea045_row5_col7" class="data row5 col7" >.</td>
#       <td id="T_ea045_row5_col8" class="data row5 col8" >.</td>
#       <td id="T_ea045_row5_col9" class="data row5 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_ea045_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ea045_row6_col0" class="data row6 col0" >.</td>
#       <td id="T_ea045_row6_col1" class="data row6 col1" >.</td>
#       <td id="T_ea045_row6_col2" class="data row6 col2" >.</td>
#       <td id="T_ea045_row6_col3" class="data row6 col3" >.</td>
#       <td id="T_ea045_row6_col4" class="data row6 col4" >.</td>
#       <td id="T_ea045_row6_col5" class="data row6 col5" >.</td>
#       <td id="T_ea045_row6_col6" class="data row6 col6" >.</td>
#       <td id="T_ea045_row6_col7" class="data row6 col7" >.</td>
#       <td id="T_ea045_row6_col8" class="data row6 col8" >.</td>
#       <td id="T_ea045_row6_col9" class="data row6 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_ea045_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ea045_row7_col0" class="data row7 col0"

# %% [markdown]
# ## Train

# %%
def progress(i, n_episod):
    clear_output(wait=True)
    print('Episod: %d/%d' % (i, n_episod - 1), end='')


episod = 200
for i in range(0, episod):
    progress(i, episod)
    obs, _ = env.reset()
    state = obs['state']
    done = False
    eps = 1 - (i + 1) / episod
    while not done:
        action = agent.get_action(state, eps)
        obs, reward, done, info = env.step(action)
        next_state = obs['state']
        agent.update(state, action, reward, next_state)
        state = next_state
# Out:
# Episod: 199/199

# %% [markdown]
# ## Check

# %%
from time import sleep


obs, _ = env.reset()
env.render()
sleep(1)

state = obs['state']
done = False
while not done:
    action = agent.get_action(state)
    obs, reward, done, info = env.step(action)
    state = obs['state']
    env.render()
    sleep(0.3)
# Out:
# <style type="text/css">
# #T_d9e15_row0_col0 {
#   color: yellow;
# }
# #T_d9e15_row0_col1, #T_d9e15_row0_col2, #T_d9e15_row0_col3, #T_d9e15_row0_col4, #T_d9e15_row0_col5, #T_d9e15_row0_col6, #T_d9e15_row0_col7, #T_d9e15_row0_col8, #T_d9e15_row0_col9, #T_d9e15_row1_col0, #T_d9e15_row1_col1, #T_d9e15_row1_col2, #T_d9e15_row1_col3, #T_d9e15_row1_col4, #T_d9e15_row1_col5, #T_d9e15_row1_col6, #T_d9e15_row1_col7, #T_d9e15_row1_col8, #T_d9e15_row1_col9, #T_d9e15_row2_col0, #T_d9e15_row2_col1, #T_d9e15_row2_col2, #T_d9e15_row2_col3, #T_d9e15_row2_col4, #T_d9e15_row2_col5, #T_d9e15_row2_col6, #T_d9e15_row2_col7, #T_d9e15_row2_col8, #T_d9e15_row2_col9, #T_d9e15_row3_col0, #T_d9e15_row3_col1, #T_d9e15_row3_col2, #T_d9e15_row3_col3, #T_d9e15_row3_col4, #T_d9e15_row3_col5, #T_d9e15_row3_col6, #T_d9e15_row3_col7, #T_d9e15_row3_col8, #T_d9e15_row3_col9, #T_d9e15_row4_col0, #T_d9e15_row4_col1, #T_d9e15_row4_col2, #T_d9e15_row4_col3, #T_d9e15_row4_col4, #T_d9e15_row4_col5, #T_d9e15_row4_col6, #T_d9e15_row4_col7, #T_d9e15_row4_col8, #T_d9e15_row4_col9, #T_d9e15_row5_col0, #T_d9e15_row5_col1, #T_d9e15_row5_col2, #T_d9e15_row5_col3, #T_d9e15_row5_col4, #T_d9e15_row5_col5, #T_d9e15_row5_col6, #T_d9e15_row5_col7, #T_d9e15_row5_col8, #T_d9e15_row5_col9, #T_d9e15_row6_col0, #T_d9e15_row6_col1, #T_d9e15_row6_col2, #T_d9e15_row6_col3, #T_d9e15_row6_col4, #T_d9e15_row6_col5, #T_d9e15_row6_col6, #T_d9e15_row6_col7, #T_d9e15_row6_col8, #T_d9e15_row6_col9, #T_d9e15_row7_col0, #T_d9e15_row7_col1, #T_d9e15_row7_col2, #T_d9e15_row7_col3, #T_d9e15_row7_col4, #T_d9e15_row7_col5, #T_d9e15_row7_col6, #T_d9e15_row7_col7, #T_d9e15_row7_col8, #T_d9e15_row7_col9, #T_d9e15_row8_col0, #T_d9e15_row8_col1, #T_d9e15_row8_col2, #T_d9e15_row8_col3, #T_d9e15_row8_col4, #T_d9e15_row8_col5, #T_d9e15_row8_col6, #T_d9e15_row8_col7, #T_d9e15_row8_col8, #T_d9e15_row8_col9, #T_d9e15_row9_col0, #T_d9e15_row9_col1, #T_d9e15_row9_col2, #T_d9e15_row9_col3, #T_d9e15_row9_col4, #T_d9e15_row9_col5, #T_d9e15_row9_col6, #T_d9e15_row9_col7, #T_d9e15_row9_col8, #T_d9e15_row9_col9 {
#   color: white;
# }
# </style>
# <table id="T_d9e15_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9e15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9e15_row0_col0" class="data row0 col0" >O</td>
#       <td id="T_d9e15_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_d9e15_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_d9e15_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_d9e15_row0_col4" class="data row0 col4" >.</td>
#       <td id="T_d9e15_row0_col5" class="data row0 col5" >.</td>
#       <td id="T_d9e15_row0_col6" class="data row0 col6" >.</td>
#       <td id="T_d9e15_row0_col7" class="data row0 col7" >.</td>
#       <td id="T_d9e15_row0_col8" class="data row0 col8" >.</td>
#       <td id="T_d9e15_row0_col9" class="data row0 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_d9e15_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9e15_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_d9e15_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_d9e15_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_d9e15_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_d9e15_row1_col4" class="data row1 col4" >.</td>
#       <td id="T_d9e15_row1_col5" class="data row1 col5" >.</td>
#       <td id="T_d9e15_row1_col6" class="data row1 col6" >.</td>
#       <td id="T_d9e15_row1_col7" class="data row1 col7" >.</td>
#       <td id="T_d9e15_row1_col8" class="data row1 col8" >.</td>
#       <td id="T_d9e15_row1_col9" class="data row1 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_d9e15_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9e15_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_d9e15_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_d9e15_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_d9e15_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_d9e15_row2_col4" class="data row2 col4" >.</td>
#       <td id="T_d9e15_row2_col5" class="data row2 col5" >.</td>
#       <td id="T_d9e15_row2_col6" class="data row2 col6" >.</td>
#       <td id="T_d9e15_row2_col7" class="data row2 col7" >.</td>
#       <td id="T_d9e15_row2_col8" class="data row2 col8" >.</td>
#       <td id="T_d9e15_row2_col9" class="data row2 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_d9e15_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9e15_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_d9e15_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_d9e15_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_d9e15_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_d9e15_row3_col4" class="data row3 col4" >.</td>
#       <td id="T_d9e15_row3_col5" class="data row3 col5" >.</td>
#       <td id="T_d9e15_row3_col6" class="data row3 col6" >.</td>
#       <td id="T_d9e15_row3_col7" class="data row3 col7" >.</td>
#       <td id="T_d9e15_row3_col8" class="data row3 col8" >.</td>
#       <td id="T_d9e15_row3_col9" class="data row3 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_d9e15_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9e15_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_d9e15_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_d9e15_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_d9e15_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_d9e15_row4_col4" class="data row4 col4" >.</td>
#       <td id="T_d9e15_row4_col5" class="data row4 col5" >.</td>
#       <td id="T_d9e15_row4_col6" class="data row4 col6" >.</td>
#       <td id="T_d9e15_row4_col7" class="data row4 col7" >.</td>
#       <td id="T_d9e15_row4_col8" class="data row4 col8" >.</td>
#       <td id="T_d9e15_row4_col9" class="data row4 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_d9e15_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9e15_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_d9e15_row5_col1" class="data row5 col1" >.</td>
#       <td id="T_d9e15_row5_col2" class="data row5 col2" >.</td>
#       <td id="T_d9e15_row5_col3" class="data row5 col3" >.</td>
#       <td id="T_d9e15_row5_col4" class="data row5 col4" >.</td>
#       <td id="T_d9e15_row5_col5" class="data row5 col5" >.</td>
#       <td id="T_d9e15_row5_col6" class="data row5 col6" >.</td>
#       <td id="T_d9e15_row5_col7" class="data row5 col7" >.</td>
#       <td id="T_d9e15_row5_col8" class="data row5 col8" >.</td>
#       <td id="T_d9e15_row5_col9" class="data row5 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_d9e15_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9e15_row6_col0" class="data row6 col0" >.</td>
#       <td id="T_d9e15_row6_col1" class="data row6 col1" >.</td>
#       <td id="T_d9e15_row6_col2" class="data row6 col2" >.</td>
#       <td id="T_d9e15_row6_col3" class="data row6 col3" >.</td>
#       <td id="T_d9e15_row6_col4" class="data row6 col4" >.</td>
#       <td id="T_d9e15_row6_col5" class="data row6 col5" >.</td>
#       <td id="T_d9e15_row6_col6" class="data row6 col6" >.</td>
#       <td id="T_d9e15_row6_col7" class="data row6 col7" >.</td>
#       <td id="T_d9e15_row6_col8" class="data row6 col8" >.</td>
#       <td id="T_d9e15_row6_col9" class="data row6 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_d9e15_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9e15_row7_col0" class="data row7 col0" >.</td>
#       <t

# %% [markdown]
# ## Save

# %%
import pickle


with open('target.gym', 'wb') as file:
    pickle.dump(target, file)

with open('agent_tab.gym', 'wb') as file:
    pickle.dump(agent, file)

# %% [markdown]
# # Networks

# %%
import torch


DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## FC

# %%
class QNet(torch.nn.Module):
    def __init__(self, states_dim, actions_dim, n_neurons=128):
        super(QNet, self).__init__()
        self.fc1 = torch.nn.Linear(states_dim, n_neurons)
        self.act1 = torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(n_neurons, n_neurons)
        self.act2 = torch.nn.ReLU()
        self.fc3 = torch.nn.Linear(n_neurons, actions_dim)
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.act1(x)
        x = self.fc2(x)
        x = self.act2(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# ## Conv

# %%
class QConv(torch.nn.Module):
    def __init__(self, size, actions_dim):
        super(QConv, self).__init__()
        self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=6, kernel_size=3, padding=2)
        self.actv1 = torch.nn.ReLU()
        self.pool1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=3, padding=0)
        self.actv2 = torch.nn.ReLU()
        self.pool2 = torch.nn.MaxPool2d(kernel_size=2, stride=2)

        n = ((((size - 3 + 2 * 2) + 1)//2 - 3) + 1) // 2
        self.fc1 = torch.nn.Linear(n * n * 16, 128)
        self.actv3 = torch.nn.ReLU()
        
        self.fc2 = torch.nn.Linear(128, 32)
        self.actv4 = torch.nn.ReLU()
        
        self.fc3 = torch.nn.Linear(32, actions_dim)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.actv1(x)
        x = self.pool1(x)
                
        x = self.conv2(x)
        x = self.actv2(x)
        x = self.pool2(x)
        
        x = x.view(x.size(0) * x.size(1) * x.size(2))
        x = self.fc1(x)
        x = self.actv3(x)
        x = self.fc2(x)
        x = self.actv4(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# # DQN

# %% [markdown]
# ## Network Agent

# %%
class NetAgent(Agent):
    def __init__(self, size, mode='fc'):
        super().__init__(size)
        self.net = QNet(states_dim=5, actions_dim=5).to(DEVICE) if mode == 'fc' \
                   else QConv(size, actions_dim=5).to(DEVICE)
        self.loss = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=1e-3, weight_decay=1e-5)
        self.gamma = 0.6
        self.epsilon = 0.2

    def get_action(self, state, epsilon=-1):
        if np.random.uniform(0, 1) < epsilon:
            return np.random.randint(5)
        state = torch.FloatTensor(state).to(DEVICE)
        q_values = self.net(state).reshape(-1)
        return int(q_values.argmax())

    def update(self, state, action, reward, done, next_state):
        state = torch.FloatTensor(state).to(DEVICE)
        next_state = torch.FloatTensor(next_state).to(DEVICE)

        old_value = self.net(state).reshape(-1)[action]
        next_max = self.net(next_state).reshape(-1).max()
        new_value = reward + self.gamma * (1 - done) * next_max

        self.optimizer.zero_grad()
        loss_val = self.loss(old_value, new_value)
        loss_val.backward()
        self.optimizer.step()

    def stop_train(self):
        self.net.eval()

    def start_train(self):
        self.net.train()

# %% [markdown]
# ## Init

# %%
from time import sleep
import random
random.seed = SEED
np.random.seed = SEED
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True


size = 10
type_agent = 'conv'
agent_net = NetAgent(size, mode=type_agent)
# target = Target(size)
# env = HunterWorldEnv(agent, target, size, 'network')
env.reset()
env.render()
# Out:
# <style type="text/css">
# #T_7cf9a_row0_col0 {
#   color: blue;
# }
# #T_7cf9a_row0_col1, #T_7cf9a_row0_col2, #T_7cf9a_row0_col3, #T_7cf9a_row0_col4, #T_7cf9a_row0_col5, #T_7cf9a_row0_col6, #T_7cf9a_row0_col7, #T_7cf9a_row0_col8, #T_7cf9a_row0_col9, #T_7cf9a_row1_col0, #T_7cf9a_row1_col2, #T_7cf9a_row1_col3, #T_7cf9a_row1_col4, #T_7cf9a_row1_col5, #T_7cf9a_row1_col6, #T_7cf9a_row1_col7, #T_7cf9a_row1_col8, #T_7cf9a_row1_col9, #T_7cf9a_row2_col0, #T_7cf9a_row2_col1, #T_7cf9a_row2_col2, #T_7cf9a_row2_col3, #T_7cf9a_row2_col4, #T_7cf9a_row2_col5, #T_7cf9a_row2_col6, #T_7cf9a_row2_col7, #T_7cf9a_row2_col8, #T_7cf9a_row2_col9, #T_7cf9a_row3_col0, #T_7cf9a_row3_col1, #T_7cf9a_row3_col2, #T_7cf9a_row3_col3, #T_7cf9a_row3_col4, #T_7cf9a_row3_col5, #T_7cf9a_row3_col6, #T_7cf9a_row3_col7, #T_7cf9a_row3_col8, #T_7cf9a_row3_col9, #T_7cf9a_row4_col0, #T_7cf9a_row4_col1, #T_7cf9a_row4_col2, #T_7cf9a_row4_col3, #T_7cf9a_row4_col4, #T_7cf9a_row4_col5, #T_7cf9a_row4_col6, #T_7cf9a_row4_col7, #T_7cf9a_row4_col8, #T_7cf9a_row4_col9, #T_7cf9a_row5_col0, #T_7cf9a_row5_col1, #T_7cf9a_row5_col2, #T_7cf9a_row5_col3, #T_7cf9a_row5_col4, #T_7cf9a_row5_col5, #T_7cf9a_row5_col6, #T_7cf9a_row5_col7, #T_7cf9a_row5_col8, #T_7cf9a_row5_col9, #T_7cf9a_row6_col0, #T_7cf9a_row6_col1, #T_7cf9a_row6_col2, #T_7cf9a_row6_col3, #T_7cf9a_row6_col4, #T_7cf9a_row6_col5, #T_7cf9a_row6_col6, #T_7cf9a_row6_col7, #T_7cf9a_row6_col8, #T_7cf9a_row6_col9, #T_7cf9a_row7_col0, #T_7cf9a_row7_col1, #T_7cf9a_row7_col2, #T_7cf9a_row7_col3, #T_7cf9a_row7_col4, #T_7cf9a_row7_col5, #T_7cf9a_row7_col6, #T_7cf9a_row7_col7, #T_7cf9a_row7_col8, #T_7cf9a_row7_col9, #T_7cf9a_row8_col0, #T_7cf9a_row8_col1, #T_7cf9a_row8_col2, #T_7cf9a_row8_col3, #T_7cf9a_row8_col4, #T_7cf9a_row8_col5, #T_7cf9a_row8_col6, #T_7cf9a_row8_col7, #T_7cf9a_row8_col8, #T_7cf9a_row8_col9, #T_7cf9a_row9_col0, #T_7cf9a_row9_col1, #T_7cf9a_row9_col2, #T_7cf9a_row9_col3, #T_7cf9a_row9_col4, #T_7cf9a_row9_col5, #T_7cf9a_row9_col6, #T_7cf9a_row9_col7, #T_7cf9a_row9_col8, #T_7cf9a_row9_col9 {
#   color: white;
# }
# #T_7cf9a_row1_col1 {
#   color: green;
# }
# </style>
# <table id="T_7cf9a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cf9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cf9a_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_7cf9a_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_7cf9a_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_7cf9a_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_7cf9a_row0_col4" class="data row0 col4" >.</td>
#       <td id="T_7cf9a_row0_col5" class="data row0 col5" >.</td>
#       <td id="T_7cf9a_row0_col6" class="data row0 col6" >.</td>
#       <td id="T_7cf9a_row0_col7" class="data row0 col7" >.</td>
#       <td id="T_7cf9a_row0_col8" class="data row0 col8" >.</td>
#       <td id="T_7cf9a_row0_col9" class="data row0 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_7cf9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7cf9a_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_7cf9a_row1_col1" class="data row1 col1" >T</td>
#       <td id="T_7cf9a_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_7cf9a_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_7cf9a_row1_col4" class="data row1 col4" >.</td>
#       <td id="T_7cf9a_row1_col5" class="data row1 col5" >.</td>
#       <td id="T_7cf9a_row1_col6" class="data row1 col6" >.</td>
#       <td id="T_7cf9a_row1_col7" class="data row1 col7" >.</td>
#       <td id="T_7cf9a_row1_col8" class="data row1 col8" >.</td>
#       <td id="T_7cf9a_row1_col9" class="data row1 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_7cf9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7cf9a_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_7cf9a_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_7cf9a_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_7cf9a_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_7cf9a_row2_col4" class="data row2 col4" >.</td>
#       <td id="T_7cf9a_row2_col5" class="data row2 col5" >.</td>
#       <td id="T_7cf9a_row2_col6" class="data row2 col6" >.</td>
#       <td id="T_7cf9a_row2_col7" class="data row2 col7" >.</td>
#       <td id="T_7cf9a_row2_col8" class="data row2 col8" >.</td>
#       <td id="T_7cf9a_row2_col9" class="data row2 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_7cf9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7cf9a_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_7cf9a_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_7cf9a_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_7cf9a_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_7cf9a_row3_col4" class="data row3 col4" >.</td>
#       <td id="T_7cf9a_row3_col5" class="data row3 col5" >.</td>
#       <td id="T_7cf9a_row3_col6" class="data row3 col6" >.</td>
#       <td id="T_7cf9a_row3_col7" class="data row3 col7" >.</td>
#       <td id="T_7cf9a_row3_col8" class="data row3 col8" >.</td>
#       <td id="T_7cf9a_row3_col9" class="data row3 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_7cf9a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7cf9a_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_7cf9a_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_7cf9a_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_7cf9a_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_7cf9a_row4_col4" class="data row4 col4" >.</td>
#       <td id="T_7cf9a_row4_col5" class="data row4 col5" >.</td>
#       <td id="T_7cf9a_row4_col6" class="data row4 col6" >.</td>
#       <td id="T_7cf9a_row4_col7" class="data row4 col7" >.</td>
#       <td id="T_7cf9a_row4_col8" class="data row4 col8" >.</td>
#       <td id="T_7cf9a_row4_col9" class="data row4 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_7cf9a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7cf9a_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_7cf9a_row5_col1" class="data row5 col1" >.</td>
#       <td id="T_7cf9a_row5_col2" class="data row5 col2" >.</td>
#       <td id="T_7cf9a_row5_col3" class="data row5 col3" >.</td>
#       <td id="T_7cf9a_row5_col4" class="data row5 col4" >.</td>
#       <td id="T_7cf9a_row5_col5" class="data row5 col5" >.</td>
#       <td id="T_7cf9a_row5_col6" class="data row5 col6" >.</td>
#       <td id="T_7cf9a_row5_col7" class="data row5 col7" >.</td>
#       <td id="T_7cf9a_row5_col8" class="data row5 col8" >.</td>
#       <td id="T_7cf9a_row5_col9" class="data row5 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_7cf9a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7cf9a_row6_col0" class="data row6 col0" >.</td>
#       <td id="T_7cf9a_row6_col1" class="data row6 col1" >.</td>
#       <td id="T_7cf9a_row6_col2" class="data row6 col2" >.</td>
#       <td id="T_7cf9a_row6_col3" class="data row6 col3" >.</td>
#       <td id="T_7cf9a_row6_col4" class="data row6 col4" >.</td>
#       <td id="T_7cf9a_row6_col5" class="data row6 col5" >.</td>
#       <td id="T_7cf9a_row6_col6" class="data row6 col6" >.</td>
#       <td id="T_7cf9a_row6_col7" class="data row6 col7" >.</td>
#       <td id="T_7cf9a_row6_col8" class="data row6 col8" >.</td>
#       <td id="T_7cf9a_row6_col9" class="data row6 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_7cf9a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7cf9a_row7_col0" class="data row7 col0"

# %% [markdown]
# ## Train

# %%
def progress(i, n_episod):
    clear_output(wait=True)
    print('Episod: %d/%d' % (i, n_episod - 1), end='')


agent_net.start_train()
env.render_mode = 'network'
episod = 1000
for i in range(0, episod):
    progress(i, episod)
    obs, _ = env.reset()
    if type_agent == 'conv':
        state = env.render()
    else:
        state = obs['state']
    done = False
    eps = 1 - (i + 1) / episod
    while not done:
        action = agent_net.get_action(state, eps)
        obs, reward, done, info = env.step(action)
        if type_agent == 'conv':
            next_state = env.render()
        else:
            next_state = obs['state']
        agent_net.update(state, action, reward, done, next_state)
        state = next_state
# Out:
# Episod: 999/999

# %% [markdown]
# ## Check

# %%
from time import sleep


agent_net.stop_train()
obs, _ = env.reset()
env.render_mode = 'human'
env.render()
sleep(1)

env.render_mode = 'network'
if type_agent == 'conv':
    state = env.render()
else:
    state = obs['state']
done = False
while not done:
    action = agent_net.get_action(state)
    obs, reward, done, info = env.step(action)
    env.render_mode = 'network'
    if type_agent == 'conv':
        state = env.render()
    else:
        state = obs['state']
    env.render_mode = 'human'
    env.render()
    sleep(0.3)
# Out:
# <style type="text/css">
# #T_edea7_row0_col0 {
#   color: yellow;
# }
# #T_edea7_row0_col1, #T_edea7_row0_col2, #T_edea7_row0_col3, #T_edea7_row0_col4, #T_edea7_row0_col5, #T_edea7_row0_col6, #T_edea7_row0_col7, #T_edea7_row0_col8, #T_edea7_row0_col9, #T_edea7_row1_col0, #T_edea7_row1_col1, #T_edea7_row1_col2, #T_edea7_row1_col3, #T_edea7_row1_col4, #T_edea7_row1_col5, #T_edea7_row1_col6, #T_edea7_row1_col7, #T_edea7_row1_col8, #T_edea7_row1_col9, #T_edea7_row2_col0, #T_edea7_row2_col1, #T_edea7_row2_col2, #T_edea7_row2_col3, #T_edea7_row2_col4, #T_edea7_row2_col5, #T_edea7_row2_col6, #T_edea7_row2_col7, #T_edea7_row2_col8, #T_edea7_row2_col9, #T_edea7_row3_col0, #T_edea7_row3_col1, #T_edea7_row3_col2, #T_edea7_row3_col3, #T_edea7_row3_col4, #T_edea7_row3_col5, #T_edea7_row3_col6, #T_edea7_row3_col7, #T_edea7_row3_col8, #T_edea7_row3_col9, #T_edea7_row4_col0, #T_edea7_row4_col1, #T_edea7_row4_col2, #T_edea7_row4_col3, #T_edea7_row4_col4, #T_edea7_row4_col5, #T_edea7_row4_col6, #T_edea7_row4_col7, #T_edea7_row4_col8, #T_edea7_row4_col9, #T_edea7_row5_col0, #T_edea7_row5_col1, #T_edea7_row5_col2, #T_edea7_row5_col3, #T_edea7_row5_col4, #T_edea7_row5_col5, #T_edea7_row5_col6, #T_edea7_row5_col7, #T_edea7_row5_col8, #T_edea7_row5_col9, #T_edea7_row6_col0, #T_edea7_row6_col1, #T_edea7_row6_col2, #T_edea7_row6_col3, #T_edea7_row6_col4, #T_edea7_row6_col5, #T_edea7_row6_col6, #T_edea7_row6_col7, #T_edea7_row6_col8, #T_edea7_row6_col9, #T_edea7_row7_col0, #T_edea7_row7_col1, #T_edea7_row7_col2, #T_edea7_row7_col3, #T_edea7_row7_col4, #T_edea7_row7_col5, #T_edea7_row7_col6, #T_edea7_row7_col7, #T_edea7_row7_col8, #T_edea7_row7_col9, #T_edea7_row8_col0, #T_edea7_row8_col1, #T_edea7_row8_col2, #T_edea7_row8_col3, #T_edea7_row8_col4, #T_edea7_row8_col5, #T_edea7_row8_col6, #T_edea7_row8_col7, #T_edea7_row8_col8, #T_edea7_row8_col9, #T_edea7_row9_col0, #T_edea7_row9_col1, #T_edea7_row9_col2, #T_edea7_row9_col3, #T_edea7_row9_col4, #T_edea7_row9_col5, #T_edea7_row9_col6, #T_edea7_row9_col7, #T_edea7_row9_col8, #T_edea7_row9_col9 {
#   color: white;
# }
# </style>
# <table id="T_edea7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edea7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edea7_row0_col0" class="data row0 col0" >O</td>
#       <td id="T_edea7_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_edea7_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_edea7_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_edea7_row0_col4" class="data row0 col4" >.</td>
#       <td id="T_edea7_row0_col5" class="data row0 col5" >.</td>
#       <td id="T_edea7_row0_col6" class="data row0 col6" >.</td>
#       <td id="T_edea7_row0_col7" class="data row0 col7" >.</td>
#       <td id="T_edea7_row0_col8" class="data row0 col8" >.</td>
#       <td id="T_edea7_row0_col9" class="data row0 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_edea7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edea7_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_edea7_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_edea7_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_edea7_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_edea7_row1_col4" class="data row1 col4" >.</td>
#       <td id="T_edea7_row1_col5" class="data row1 col5" >.</td>
#       <td id="T_edea7_row1_col6" class="data row1 col6" >.</td>
#       <td id="T_edea7_row1_col7" class="data row1 col7" >.</td>
#       <td id="T_edea7_row1_col8" class="data row1 col8" >.</td>
#       <td id="T_edea7_row1_col9" class="data row1 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_edea7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edea7_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_edea7_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_edea7_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_edea7_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_edea7_row2_col4" class="data row2 col4" >.</td>
#       <td id="T_edea7_row2_col5" class="data row2 col5" >.</td>
#       <td id="T_edea7_row2_col6" class="data row2 col6" >.</td>
#       <td id="T_edea7_row2_col7" class="data row2 col7" >.</td>
#       <td id="T_edea7_row2_col8" class="data row2 col8" >.</td>
#       <td id="T_edea7_row2_col9" class="data row2 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_edea7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edea7_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_edea7_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_edea7_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_edea7_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_edea7_row3_col4" class="data row3 col4" >.</td>
#       <td id="T_edea7_row3_col5" class="data row3 col5" >.</td>
#       <td id="T_edea7_row3_col6" class="data row3 col6" >.</td>
#       <td id="T_edea7_row3_col7" class="data row3 col7" >.</td>
#       <td id="T_edea7_row3_col8" class="data row3 col8" >.</td>
#       <td id="T_edea7_row3_col9" class="data row3 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_edea7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edea7_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_edea7_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_edea7_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_edea7_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_edea7_row4_col4" class="data row4 col4" >.</td>
#       <td id="T_edea7_row4_col5" class="data row4 col5" >.</td>
#       <td id="T_edea7_row4_col6" class="data row4 col6" >.</td>
#       <td id="T_edea7_row4_col7" class="data row4 col7" >.</td>
#       <td id="T_edea7_row4_col8" class="data row4 col8" >.</td>
#       <td id="T_edea7_row4_col9" class="data row4 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_edea7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_edea7_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_edea7_row5_col1" class="data row5 col1" >.</td>
#       <td id="T_edea7_row5_col2" class="data row5 col2" >.</td>
#       <td id="T_edea7_row5_col3" class="data row5 col3" >.</td>
#       <td id="T_edea7_row5_col4" class="data row5 col4" >.</td>
#       <td id="T_edea7_row5_col5" class="data row5 col5" >.</td>
#       <td id="T_edea7_row5_col6" class="data row5 col6" >.</td>
#       <td id="T_edea7_row5_col7" class="data row5 col7" >.</td>
#       <td id="T_edea7_row5_col8" class="data row5 col8" >.</td>
#       <td id="T_edea7_row5_col9" class="data row5 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_edea7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_edea7_row6_col0" class="data row6 col0" >.</td>
#       <td id="T_edea7_row6_col1" class="data row6 col1" >.</td>
#       <td id="T_edea7_row6_col2" class="data row6 col2" >.</td>
#       <td id="T_edea7_row6_col3" class="data row6 col3" >.</td>
#       <td id="T_edea7_row6_col4" class="data row6 col4" >.</td>
#       <td id="T_edea7_row6_col5" class="data row6 col5" >.</td>
#       <td id="T_edea7_row6_col6" class="data row6 col6" >.</td>
#       <td id="T_edea7_row6_col7" class="data row6 col7" >.</td>
#       <td id="T_edea7_row6_col8" class="data row6 col8" >.</td>
#       <td id="T_edea7_row6_col9" class="data row6 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_edea7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_edea7_row7_col0" class="data row7 col0" >.</td>
#       <t

# %% [markdown]
# ## Save

# %%
import pickle


with open('agent_net.gym', 'wb') as file:
    pickle.dump(agent_net, file)

# %%
torch.save(agent_net.net, 'net_by_agentnet.pth')

# %% [markdown]
# # Hybrid

# %% [markdown]
# ## Hybrid Agent

# %%
class HybridAgent(Agent):
    def __init__(self, size, type_net='fc'):
        super().__init__(size)
        self.type_net = type_net
        self.net = QNet(states_dim=5, actions_dim=5).to(DEVICE) if type_net == 'fc' \
                   else QConv(size, actions_dim=5).to(DEVICE)
        self.loss = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=1e-3, weight_decay=1e-5)
        self.q_table = np.zeros((size, size, 2, size, size, 5))
        self.alpha = 0.1
        self.gamma = 0.6
        self.epsilon = 0.2

    def get_action(self, state, render, epsilon=-1, mode='net'):
        if np.random.uniform(0, 1) < epsilon:
            return np.random.randint(5)

        if mode == 'net':
            render = torch.FloatTensor(render).to(DEVICE)
            state = torch.FloatTensor(state).to(DEVICE)
            if self.type_net == 'fc':
                q_values = self.net(state).reshape(-1)
            else:
                q_values = self.net(render).reshape(-1)
            return int(q_values.argmax())

        return np.argmax(self.q_table[state[0], state[1], state[2], 
                                      state[3], state[4]])
        
    def update(self, state, action, reward, render, next_state):
        old_value = self.q_table[state[0], state[1], state[2], state[3], 
                                 state[4], action]
        next_max = np.max(self.q_table[next_state[0], next_state[1], next_state[2], 
                                       next_state[3], next_state[4]])
        new_value = (1 - self.alpha) * old_value + self.alpha * (reward + self.gamma * next_max)
        self.q_table[state[0], state[1], state[2], state[3], state[4], action] = new_value


        state_ = torch.FloatTensor(state).to(DEVICE)
        render = torch.FloatTensor(render).to(DEVICE)
        if self.type_net == 'fc':
            pred = self.net(state_).reshape(-1)[action]
        else:
            pred = self.net(render).reshape(-1)[action]
        
        self.optimizer.zero_grad()
        loss_val = self.loss(pred, torch.FloatTensor([new_value]).to(DEVICE))
        loss_val.backward()
        self.optimizer.step()

    def stop_train(self):
        self.net.eval()

    def start_train(self):
        self.net.train()

# %% [markdown]
# ## Init

# %%
from time import sleep
import random
random.seed = SEED
np.random.seed = SEED
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True


size = 10
agent_hyb = HybridAgent(size, type_net='conv')
#target = Target(size)
#env = HunterWorldEnv(agent, target, size, 'network')
env.reset()
env.render()
# Out:
# <style type="text/css">
# #T_c3c70_row0_col0 {
#   color: blue;
# }
# #T_c3c70_row0_col1, #T_c3c70_row0_col2, #T_c3c70_row0_col3, #T_c3c70_row0_col4, #T_c3c70_row0_col5, #T_c3c70_row0_col6, #T_c3c70_row0_col7, #T_c3c70_row0_col8, #T_c3c70_row0_col9, #T_c3c70_row1_col0, #T_c3c70_row1_col2, #T_c3c70_row1_col3, #T_c3c70_row1_col4, #T_c3c70_row1_col5, #T_c3c70_row1_col6, #T_c3c70_row1_col7, #T_c3c70_row1_col8, #T_c3c70_row1_col9, #T_c3c70_row2_col0, #T_c3c70_row2_col1, #T_c3c70_row2_col2, #T_c3c70_row2_col3, #T_c3c70_row2_col4, #T_c3c70_row2_col5, #T_c3c70_row2_col6, #T_c3c70_row2_col7, #T_c3c70_row2_col8, #T_c3c70_row2_col9, #T_c3c70_row3_col0, #T_c3c70_row3_col1, #T_c3c70_row3_col2, #T_c3c70_row3_col3, #T_c3c70_row3_col4, #T_c3c70_row3_col5, #T_c3c70_row3_col6, #T_c3c70_row3_col7, #T_c3c70_row3_col8, #T_c3c70_row3_col9, #T_c3c70_row4_col0, #T_c3c70_row4_col1, #T_c3c70_row4_col2, #T_c3c70_row4_col3, #T_c3c70_row4_col4, #T_c3c70_row4_col5, #T_c3c70_row4_col6, #T_c3c70_row4_col7, #T_c3c70_row4_col8, #T_c3c70_row4_col9, #T_c3c70_row5_col0, #T_c3c70_row5_col1, #T_c3c70_row5_col2, #T_c3c70_row5_col3, #T_c3c70_row5_col4, #T_c3c70_row5_col5, #T_c3c70_row5_col6, #T_c3c70_row5_col7, #T_c3c70_row5_col8, #T_c3c70_row5_col9, #T_c3c70_row6_col0, #T_c3c70_row6_col1, #T_c3c70_row6_col2, #T_c3c70_row6_col3, #T_c3c70_row6_col4, #T_c3c70_row6_col5, #T_c3c70_row6_col6, #T_c3c70_row6_col7, #T_c3c70_row6_col8, #T_c3c70_row6_col9, #T_c3c70_row7_col0, #T_c3c70_row7_col1, #T_c3c70_row7_col2, #T_c3c70_row7_col3, #T_c3c70_row7_col4, #T_c3c70_row7_col5, #T_c3c70_row7_col6, #T_c3c70_row7_col7, #T_c3c70_row7_col8, #T_c3c70_row7_col9, #T_c3c70_row8_col0, #T_c3c70_row8_col1, #T_c3c70_row8_col2, #T_c3c70_row8_col3, #T_c3c70_row8_col4, #T_c3c70_row8_col5, #T_c3c70_row8_col6, #T_c3c70_row8_col7, #T_c3c70_row8_col8, #T_c3c70_row8_col9, #T_c3c70_row9_col0, #T_c3c70_row9_col1, #T_c3c70_row9_col2, #T_c3c70_row9_col3, #T_c3c70_row9_col4, #T_c3c70_row9_col5, #T_c3c70_row9_col6, #T_c3c70_row9_col7, #T_c3c70_row9_col8, #T_c3c70_row9_col9 {
#   color: white;
# }
# #T_c3c70_row1_col1 {
#   color: green;
# }
# </style>
# <table id="T_c3c70_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3c70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3c70_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_c3c70_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_c3c70_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_c3c70_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_c3c70_row0_col4" class="data row0 col4" >.</td>
#       <td id="T_c3c70_row0_col5" class="data row0 col5" >.</td>
#       <td id="T_c3c70_row0_col6" class="data row0 col6" >.</td>
#       <td id="T_c3c70_row0_col7" class="data row0 col7" >.</td>
#       <td id="T_c3c70_row0_col8" class="data row0 col8" >.</td>
#       <td id="T_c3c70_row0_col9" class="data row0 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c3c70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3c70_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_c3c70_row1_col1" class="data row1 col1" >T</td>
#       <td id="T_c3c70_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_c3c70_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_c3c70_row1_col4" class="data row1 col4" >.</td>
#       <td id="T_c3c70_row1_col5" class="data row1 col5" >.</td>
#       <td id="T_c3c70_row1_col6" class="data row1 col6" >.</td>
#       <td id="T_c3c70_row1_col7" class="data row1 col7" >.</td>
#       <td id="T_c3c70_row1_col8" class="data row1 col8" >.</td>
#       <td id="T_c3c70_row1_col9" class="data row1 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c3c70_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3c70_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_c3c70_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_c3c70_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_c3c70_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_c3c70_row2_col4" class="data row2 col4" >.</td>
#       <td id="T_c3c70_row2_col5" class="data row2 col5" >.</td>
#       <td id="T_c3c70_row2_col6" class="data row2 col6" >.</td>
#       <td id="T_c3c70_row2_col7" class="data row2 col7" >.</td>
#       <td id="T_c3c70_row2_col8" class="data row2 col8" >.</td>
#       <td id="T_c3c70_row2_col9" class="data row2 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c3c70_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3c70_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_c3c70_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_c3c70_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_c3c70_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_c3c70_row3_col4" class="data row3 col4" >.</td>
#       <td id="T_c3c70_row3_col5" class="data row3 col5" >.</td>
#       <td id="T_c3c70_row3_col6" class="data row3 col6" >.</td>
#       <td id="T_c3c70_row3_col7" class="data row3 col7" >.</td>
#       <td id="T_c3c70_row3_col8" class="data row3 col8" >.</td>
#       <td id="T_c3c70_row3_col9" class="data row3 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c3c70_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3c70_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_c3c70_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_c3c70_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_c3c70_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_c3c70_row4_col4" class="data row4 col4" >.</td>
#       <td id="T_c3c70_row4_col5" class="data row4 col5" >.</td>
#       <td id="T_c3c70_row4_col6" class="data row4 col6" >.</td>
#       <td id="T_c3c70_row4_col7" class="data row4 col7" >.</td>
#       <td id="T_c3c70_row4_col8" class="data row4 col8" >.</td>
#       <td id="T_c3c70_row4_col9" class="data row4 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c3c70_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3c70_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_c3c70_row5_col1" class="data row5 col1" >.</td>
#       <td id="T_c3c70_row5_col2" class="data row5 col2" >.</td>
#       <td id="T_c3c70_row5_col3" class="data row5 col3" >.</td>
#       <td id="T_c3c70_row5_col4" class="data row5 col4" >.</td>
#       <td id="T_c3c70_row5_col5" class="data row5 col5" >.</td>
#       <td id="T_c3c70_row5_col6" class="data row5 col6" >.</td>
#       <td id="T_c3c70_row5_col7" class="data row5 col7" >.</td>
#       <td id="T_c3c70_row5_col8" class="data row5 col8" >.</td>
#       <td id="T_c3c70_row5_col9" class="data row5 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c3c70_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3c70_row6_col0" class="data row6 col0" >.</td>
#       <td id="T_c3c70_row6_col1" class="data row6 col1" >.</td>
#       <td id="T_c3c70_row6_col2" class="data row6 col2" >.</td>
#       <td id="T_c3c70_row6_col3" class="data row6 col3" >.</td>
#       <td id="T_c3c70_row6_col4" class="data row6 col4" >.</td>
#       <td id="T_c3c70_row6_col5" class="data row6 col5" >.</td>
#       <td id="T_c3c70_row6_col6" class="data row6 col6" >.</td>
#       <td id="T_c3c70_row6_col7" class="data row6 col7" >.</td>
#       <td id="T_c3c70_row6_col8" class="data row6 col8" >.</td>
#       <td id="T_c3c70_row6_col9" class="data row6 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c3c70_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3c70_row7_col0" class="data row7 col0"

# %% [markdown]
# ## Train

# %%
def progress(i, n_episod):
    clear_output(wait=True)
    print('Episod: %d/%d' % (i, n_episod - 1), end='')


env.render_mode = 'network'
agent_hyb.start_train()
episod = 1000
for i in range(0, episod):
    progress(i, episod)
    obs, _ = env.reset()
    state = obs['state']
    render = env.render()
    done = False
    eps = 1 - (i + 1) / episod
    while not done:
        action = agent_hyb.get_action(state, render, eps, mode='table')
        obs, reward, done, info = env.step(action)
        next_state = obs['state']
        agent_hyb.update(state, action, reward, render, next_state)
        state = next_state
        render = env.render()
# Out:
# Episod: 999/999

# %% [markdown]
# ## Check

# %%
from time import sleep

agent_hyb.stop_train()
obs, _ = env.reset()
env.render_mode = 'human'
state = obs['state']
env.render()
sleep(1)

env.render_mode = 'network'
render = env.render()
done = False
while not done:
    action = agent_hyb.get_action(state, render)
    obs, _, done, _ = env.step(action)
    state = obs['state']
    env.render_mode = 'network'
    render = env.render()
    env.render_mode = 'human'
    env.render()
    sleep(0.3)
# Out:
# <style type="text/css">
# #T_b6f60_row0_col0 {
#   color: yellow;
# }
# #T_b6f60_row0_col1, #T_b6f60_row0_col2, #T_b6f60_row0_col3, #T_b6f60_row0_col4, #T_b6f60_row0_col5, #T_b6f60_row0_col6, #T_b6f60_row0_col7, #T_b6f60_row0_col8, #T_b6f60_row0_col9, #T_b6f60_row1_col0, #T_b6f60_row1_col1, #T_b6f60_row1_col2, #T_b6f60_row1_col3, #T_b6f60_row1_col4, #T_b6f60_row1_col5, #T_b6f60_row1_col6, #T_b6f60_row1_col7, #T_b6f60_row1_col8, #T_b6f60_row1_col9, #T_b6f60_row2_col0, #T_b6f60_row2_col1, #T_b6f60_row2_col2, #T_b6f60_row2_col3, #T_b6f60_row2_col4, #T_b6f60_row2_col5, #T_b6f60_row2_col6, #T_b6f60_row2_col7, #T_b6f60_row2_col8, #T_b6f60_row2_col9, #T_b6f60_row3_col0, #T_b6f60_row3_col1, #T_b6f60_row3_col2, #T_b6f60_row3_col3, #T_b6f60_row3_col4, #T_b6f60_row3_col5, #T_b6f60_row3_col6, #T_b6f60_row3_col7, #T_b6f60_row3_col8, #T_b6f60_row3_col9, #T_b6f60_row4_col0, #T_b6f60_row4_col1, #T_b6f60_row4_col2, #T_b6f60_row4_col3, #T_b6f60_row4_col4, #T_b6f60_row4_col5, #T_b6f60_row4_col6, #T_b6f60_row4_col7, #T_b6f60_row4_col8, #T_b6f60_row4_col9, #T_b6f60_row5_col0, #T_b6f60_row5_col1, #T_b6f60_row5_col2, #T_b6f60_row5_col3, #T_b6f60_row5_col4, #T_b6f60_row5_col5, #T_b6f60_row5_col6, #T_b6f60_row5_col7, #T_b6f60_row5_col8, #T_b6f60_row5_col9, #T_b6f60_row6_col0, #T_b6f60_row6_col1, #T_b6f60_row6_col2, #T_b6f60_row6_col3, #T_b6f60_row6_col4, #T_b6f60_row6_col5, #T_b6f60_row6_col6, #T_b6f60_row6_col7, #T_b6f60_row6_col8, #T_b6f60_row6_col9, #T_b6f60_row7_col0, #T_b6f60_row7_col1, #T_b6f60_row7_col2, #T_b6f60_row7_col3, #T_b6f60_row7_col4, #T_b6f60_row7_col5, #T_b6f60_row7_col6, #T_b6f60_row7_col7, #T_b6f60_row7_col8, #T_b6f60_row7_col9, #T_b6f60_row8_col0, #T_b6f60_row8_col1, #T_b6f60_row8_col2, #T_b6f60_row8_col3, #T_b6f60_row8_col4, #T_b6f60_row8_col5, #T_b6f60_row8_col6, #T_b6f60_row8_col7, #T_b6f60_row8_col8, #T_b6f60_row8_col9, #T_b6f60_row9_col0, #T_b6f60_row9_col1, #T_b6f60_row9_col2, #T_b6f60_row9_col3, #T_b6f60_row9_col4, #T_b6f60_row9_col5, #T_b6f60_row9_col6, #T_b6f60_row9_col7, #T_b6f60_row9_col8, #T_b6f60_row9_col9 {
#   color: white;
# }
# </style>
# <table id="T_b6f60_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6f60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6f60_row0_col0" class="data row0 col0" >O</td>
#       <td id="T_b6f60_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_b6f60_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_b6f60_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_b6f60_row0_col4" class="data row0 col4" >.</td>
#       <td id="T_b6f60_row0_col5" class="data row0 col5" >.</td>
#       <td id="T_b6f60_row0_col6" class="data row0 col6" >.</td>
#       <td id="T_b6f60_row0_col7" class="data row0 col7" >.</td>
#       <td id="T_b6f60_row0_col8" class="data row0 col8" >.</td>
#       <td id="T_b6f60_row0_col9" class="data row0 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b6f60_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6f60_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_b6f60_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_b6f60_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_b6f60_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_b6f60_row1_col4" class="data row1 col4" >.</td>
#       <td id="T_b6f60_row1_col5" class="data row1 col5" >.</td>
#       <td id="T_b6f60_row1_col6" class="data row1 col6" >.</td>
#       <td id="T_b6f60_row1_col7" class="data row1 col7" >.</td>
#       <td id="T_b6f60_row1_col8" class="data row1 col8" >.</td>
#       <td id="T_b6f60_row1_col9" class="data row1 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b6f60_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6f60_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_b6f60_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_b6f60_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_b6f60_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_b6f60_row2_col4" class="data row2 col4" >.</td>
#       <td id="T_b6f60_row2_col5" class="data row2 col5" >.</td>
#       <td id="T_b6f60_row2_col6" class="data row2 col6" >.</td>
#       <td id="T_b6f60_row2_col7" class="data row2 col7" >.</td>
#       <td id="T_b6f60_row2_col8" class="data row2 col8" >.</td>
#       <td id="T_b6f60_row2_col9" class="data row2 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b6f60_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6f60_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_b6f60_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_b6f60_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_b6f60_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_b6f60_row3_col4" class="data row3 col4" >.</td>
#       <td id="T_b6f60_row3_col5" class="data row3 col5" >.</td>
#       <td id="T_b6f60_row3_col6" class="data row3 col6" >.</td>
#       <td id="T_b6f60_row3_col7" class="data row3 col7" >.</td>
#       <td id="T_b6f60_row3_col8" class="data row3 col8" >.</td>
#       <td id="T_b6f60_row3_col9" class="data row3 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b6f60_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6f60_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_b6f60_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_b6f60_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_b6f60_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_b6f60_row4_col4" class="data row4 col4" >.</td>
#       <td id="T_b6f60_row4_col5" class="data row4 col5" >.</td>
#       <td id="T_b6f60_row4_col6" class="data row4 col6" >.</td>
#       <td id="T_b6f60_row4_col7" class="data row4 col7" >.</td>
#       <td id="T_b6f60_row4_col8" class="data row4 col8" >.</td>
#       <td id="T_b6f60_row4_col9" class="data row4 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b6f60_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6f60_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_b6f60_row5_col1" class="data row5 col1" >.</td>
#       <td id="T_b6f60_row5_col2" class="data row5 col2" >.</td>
#       <td id="T_b6f60_row5_col3" class="data row5 col3" >.</td>
#       <td id="T_b6f60_row5_col4" class="data row5 col4" >.</td>
#       <td id="T_b6f60_row5_col5" class="data row5 col5" >.</td>
#       <td id="T_b6f60_row5_col6" class="data row5 col6" >.</td>
#       <td id="T_b6f60_row5_col7" class="data row5 col7" >.</td>
#       <td id="T_b6f60_row5_col8" class="data row5 col8" >.</td>
#       <td id="T_b6f60_row5_col9" class="data row5 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b6f60_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6f60_row6_col0" class="data row6 col0" >.</td>
#       <td id="T_b6f60_row6_col1" class="data row6 col1" >.</td>
#       <td id="T_b6f60_row6_col2" class="data row6 col2" >.</td>
#       <td id="T_b6f60_row6_col3" class="data row6 col3" >.</td>
#       <td id="T_b6f60_row6_col4" class="data row6 col4" >.</td>
#       <td id="T_b6f60_row6_col5" class="data row6 col5" >.</td>
#       <td id="T_b6f60_row6_col6" class="data row6 col6" >.</td>
#       <td id="T_b6f60_row6_col7" class="data row6 col7" >.</td>
#       <td id="T_b6f60_row6_col8" class="data row6 col8" >.</td>
#       <td id="T_b6f60_row6_col9" class="data row6 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b6f60_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6f60_row7_col0" class="data row7 col0" >.</td>
#       <t

# %% [markdown]
# ## Save

# %%
import pickle


with open('agent_hyb.gym', 'wb') as file:
    pickle.dump(agent_hyb, file)

# %%
torch.save(agent_hyb.net, 'net_by_agenthyb.pth')
