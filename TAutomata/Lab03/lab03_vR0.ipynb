# %% [markdown]
# # Задание  1
# Установить gym (python3 - https://github.com/openai/gym, для тех, кто делает на java - https://github.com/deeplearning4j/gym-java-client), реализовать среду из предыдущего семинара в gym, агенты - тигр и кролик. Реализовать задачу из семинара 2 в openai gym.

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def dist(self, other):
        return abs(self.x - other.x) + abs(self.y - other.y)
    
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    
    def __lt__(self, other):
        return self.x < other.x and self.y < other.y
    
    def __repr__(self):
        return '(' + str(self.x) + ', ' + str(self.y) + ')'

# %%
import gym
from gym import spaces
from IPython.display import display
from IPython.display import clear_output
import copy
import numpy as np
import pandas as pd


class HunterEnv(gym.Env):
    def __init__(self, size=10, n_enemy=4, n_pray=3):
        self.state = 0
        self.size = size
        self.loc = self.gen_loc(size, n_enemy, n_pray)
        self.action_space = spaces.Discrete(5)
        self.observation_space = spaces.Discrete(size * size * 2)
        
    def gen_loc(self, size, n_enemy, n_pray):
        loc = {'pray': [], 'enemy': []}
        tmp = [(0, 0)]
        
        for pray in range(n_pray):
            i = np.random.randint(0, size)
            j = np.random.randint(0, size)
            while (i, j) in tmp:
                i = np.random.randint(0, size)
                j = np.random.randint(0, size)
            tmp.append((i, j))
            loc['pray'].append(Point(i, j))
            
        for enemy in range(n_enemy):
            i = np.random.randint(0, size)
            j = np.random.randint(0, size)
            while (i, j) in tmp:
                i = np.random.randint(0, size)
                j = np.random.randint(0, size)
            tmp.append((i, j))
            loc['enemy'].append(Point(i, j))
            
        self.backup = copy.deepcopy(loc)
        return loc
        
    def encode(self, tiger_i, tiger_j, purpose):
        i  = tiger_i
        i *= self.size
        i += tiger_j
        i *= 2
        i += purpose
        return i
    
    def decode(self, i):
        out = []
        out.append(i % 2)
        i = i // 2
        out.append(i % self.size)
        i = i // self.size
        out.append(i)
        return reversed(out)
    
    def render(self):
        clear_output(wait=True)
        def cell_color(val):
            color = 'white'
            if val == 'T':
                color = 'blue'
            if val == '+':
                color = 'green'
            if val == 'X':
                color = 'red'
            return 'color: %s' % color
        n = self.size
        desk = np.full((n, n), '.').astype(str)
        for pray in self.loc['pray']:
            desk[pray.y][pray.x] = '+'
        for enemy in self.loc['enemy']:
            desk[enemy.y][enemy.x] = 'X'
        tiger_i, tiger_j, _ = self.decode(self.state)
        desk[tiger_i][tiger_j] = 'T'
        display(pd.DataFrame(desk).style.applymap(cell_color))
        
    def reset(self):
        self.state = 0
        self.loc['pray'] = list(self.backup['pray'])
        self.loc['enemy'] = list(self.backup['enemy'])
        self.tiger_attack = 0.1
        return 0
        
    def step(self, action):
        def check(location):
            border1 = Point(self.size, self.size)
            border2 = Point(-1, -1)
            return border2 < location < border1 and location not in self.loc['enemy']

        def pray(location):
            pray_list = self.loc['pray']
            pray = [(location.dist(pray), pray) for pray in pray_list]
            pray = min(pray)
            return pray[1]
                
        
        s = self.state
        tiger_i, tiger_j, purpose = self.decode(s)
        tiger = Point(tiger_j, tiger_i)
        p = Point(0, 0) if purpose == 1 else pray(tiger)
        
        if action == 4:
            if purpose == 0 and p == tiger:
                self.state = self.encode(tiger.y, tiger.x, 1)
                self.loc['pray'].remove(p)
                return self.state, 5000, False     
            return s, -500, False
            
        if action == 0:
            state = Point(tiger.x + 1, tiger.y)
        if action == 1:
            state = Point(tiger.x - 1, tiger.y)
        if action == 2:
            state = Point(tiger.x, tiger.y + 1)
        if action == 3:
            state = Point(tiger.x, tiger.y - 1)
            
        if not check(state):
            return s, -500, False
        
        self.state = self.encode(state.y, state.x, purpose)
        
        if state == p:
            if purpose == 0:
                return self.state, 1000, False
            if purpose == 1:
                return self.state, 5000, True
        
        return self.state, -p.dist(state), False

# %%
np.random.seed(42)


size = 10
env = HunterEnv(size=size, n_enemy=40, n_pray=3)
env.render()
# Out:
# <style type="text/css">
# #T_a9730_row0_col0 {
#   color: blue;
# }
# #T_a9730_row0_col1, #T_a9730_row0_col2, #T_a9730_row0_col4, #T_a9730_row0_col7, #T_a9730_row0_col8, #T_a9730_row1_col3, #T_a9730_row1_col5, #T_a9730_row1_col8, #T_a9730_row2_col0, #T_a9730_row2_col4, #T_a9730_row2_col5, #T_a9730_row2_col7, #T_a9730_row2_col8, #T_a9730_row2_col9, #T_a9730_row3_col1, #T_a9730_row3_col7, #T_a9730_row4_col1, #T_a9730_row4_col5, #T_a9730_row4_col6, #T_a9730_row4_col9, #T_a9730_row5_col1, #T_a9730_row5_col3, #T_a9730_row5_col9, #T_a9730_row6_col2, #T_a9730_row6_col6, #T_a9730_row6_col8, #T_a9730_row7_col1, #T_a9730_row7_col2, #T_a9730_row7_col3, #T_a9730_row7_col6, #T_a9730_row7_col7, #T_a9730_row7_col8, #T_a9730_row8_col0, #T_a9730_row8_col6, #T_a9730_row8_col8, #T_a9730_row8_col9, #T_a9730_row9_col1, #T_a9730_row9_col4, #T_a9730_row9_col5, #T_a9730_row9_col7 {
#   color: red;
# }
# #T_a9730_row0_col3, #T_a9730_row0_col5, #T_a9730_row0_col6, #T_a9730_row0_col9, #T_a9730_row1_col0, #T_a9730_row1_col1, #T_a9730_row1_col2, #T_a9730_row1_col4, #T_a9730_row1_col6, #T_a9730_row1_col7, #T_a9730_row1_col9, #T_a9730_row2_col1, #T_a9730_row2_col2, #T_a9730_row2_col3, #T_a9730_row2_col6, #T_a9730_row3_col0, #T_a9730_row3_col2, #T_a9730_row3_col3, #T_a9730_row3_col4, #T_a9730_row3_col5, #T_a9730_row3_col8, #T_a9730_row3_col9, #T_a9730_row4_col0, #T_a9730_row4_col2, #T_a9730_row4_col3, #T_a9730_row4_col4, #T_a9730_row4_col8, #T_a9730_row5_col0, #T_a9730_row5_col2, #T_a9730_row5_col4, #T_a9730_row5_col5, #T_a9730_row5_col6, #T_a9730_row5_col7, #T_a9730_row5_col8, #T_a9730_row6_col0, #T_a9730_row6_col1, #T_a9730_row6_col3, #T_a9730_row6_col4, #T_a9730_row6_col5, #T_a9730_row6_col7, #T_a9730_row6_col9, #T_a9730_row7_col0, #T_a9730_row7_col4, #T_a9730_row7_col5, #T_a9730_row7_col9, #T_a9730_row8_col1, #T_a9730_row8_col2, #T_a9730_row8_col3, #T_a9730_row8_col4, #T_a9730_row8_col5, #T_a9730_row8_col7, #T_a9730_row9_col0, #T_a9730_row9_col2, #T_a9730_row9_col3, #T_a9730_row9_col8, #T_a9730_row9_col9 {
#   color: white;
# }
# #T_a9730_row3_col6, #T_a9730_row4_col7, #T_a9730_row9_col6 {
#   color: green;
# }
# </style>
# <table id="T_a9730">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9730_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a9730_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a9730_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_a9730_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_a9730_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_a9730_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_a9730_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_a9730_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_a9730_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_a9730_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9730_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9730_row0_col0" class="data row0 col0" >T</td>
#       <td id="T_a9730_row0_col1" class="data row0 col1" >X</td>
#       <td id="T_a9730_row0_col2" class="data row0 col2" >X</td>
#       <td id="T_a9730_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_a9730_row0_col4" class="data row0 col4" >X</td>
#       <td id="T_a9730_row0_col5" class="data row0 col5" >.</td>
#       <td id="T_a9730_row0_col6" class="data row0 col6" >.</td>
#       <td id="T_a9730_row0_col7" class="data row0 col7" >X</td>
#       <td id="T_a9730_row0_col8" class="data row0 col8" >X</td>
#       <td id="T_a9730_row0_col9" class="data row0 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_a9730_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9730_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_a9730_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_a9730_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_a9730_row1_col3" class="data row1 col3" >X</td>
#       <td id="T_a9730_row1_col4" class="data row1 col4" >.</td>
#       <td id="T_a9730_row1_col5" class="data row1 col5" >X</td>
#       <td id="T_a9730_row1_col6" class="data row1 col6" >.</td>
#       <td id="T_a9730_row1_col7" class="data row1 col7" >.</td>
#       <td id="T_a9730_row1_col8" class="data row1 col8" >X</td>
#       <td id="T_a9730_row1_col9" class="data row1 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_a9730_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9730_row2_col0" class="data row2 col0" >X</td>
#       <td id="T_a9730_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_a9730_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_a9730_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_a9730_row2_col4" class="data row2 col4" >X</td>
#       <td id="T_a9730_row2_col5" class="data row2 col5" >X</td>
#       <td id="T_a9730_row2_col6" class="data row2 col6" >.</td>
#       <td id="T_a9730_row2_col7" class="data row2 col7" >X</td>
#       <td id="T_a9730_row2_col8" class="data row2 col8" >X</td>
#       <td id="T_a9730_row2_col9" class="data row2 col9" >X</td>
#     </tr>
#     <tr>
#       <th id="T_a9730_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9730_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_a9730_row3_col1" class="data row3 col1" >X</td>
#       <td id="T_a9730_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_a9730_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_a9730_row3_col4" class="data row3 col4" >.</td>
#       <td id="T_a9730_row3_col5" class="data row3 col5" >.</td>
#       <td id="T_a9730_row3_col6" class="data row3 col6" >+</td>
#       <td id="T_a9730_row3_col7" class="data row3 col7" >X</td>
#       <td id="T_a9730_row3_col8" class="data row3 col8" >.</td>
#       <td id="T_a9730_row3_col9" class="data row3 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_a9730_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9730_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_a9730_row4_col1" class="data row4 col1" >X</td>
#       <td id="T_a9730_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_a9730_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_a9730_row4_col4" class="data row4 col4" >.</td>
#       <td id="T_a9730_row4_col5" class="data row4 col5" >X</td>
#       <td id="T_a9730_row4_col6" class="data row4 col6" >X</td>
#       <td id="T_a9730_row4_col7" class="data row4 col7" >+</td>
#       <td id="T_a9730_row4_col8" class="data row4 col8" >.</td>
#       <td id="T_a9730_row4_col9" class="data row4 col9" >X</td>
#     </tr>
#     <tr>
#       <th id="T_a9730_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9730_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_a9730_row5_col1" class="data row5 col1" >X</td>
#       <td id="T_a9730_row5_col2" class="data row5 col2" >.</td>
#       <td id="T_a9730_row5_col3" class="data row5 col3" >X</td>
#       <td id="T_a9730_row5_col4" class="data row5 col4" >.</td>
#       <td id="T_a9730_row5_col5" class="data row5 col5" >.</td>
#       <td id="T_a9730_row5_col6" class="data row5 col6" >.</td>
#       <td id="T_a9730_row5_col7" class="data row5 col7" >.</td>
#       <td id="T_a9730_row5_col8" class="data row5 col8" >.</td>
#       <td id="T_a9730_row5_col9" class="data row5 col9" >X</td>
#     </tr>
#     <tr>
#       <th id="T_a9730_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9730_row6_col0" class="data row6 col0" >.</td>
#       <td id="T_a9730_row6_col1" class="data row6 col1" >.</td>
#       <td id="T_a9730_row6_col2" class="data row6 col2" >X</td>
#       <td id="T_a9730_row6_col3" class="data row6 col3" >.</td>
#       <td id="T_a9730_row6_col4" class="data row6 col4" >.</td>
#       <td id="T_a9730_row6_col5" class="data row6 col5" >.</td>
#       <td id="T_a9730_row6_col6" class="data row6 col6" >X</td>
#       <td id="T_a9730_row6_col7" class="data row6 col7" >.</td>
#       <td id="T_a9730_row6_co

# %%
def progress(i, n_episod):
    clear_output(wait=True)
    print('Epoch %d/%d: |' % (i, n_episod - 1), end='')
    for _ in range(i):
        print('-', end='')
    for _ in range(n_episod - i - 1):
        print(' ', end='')
    print('|')


q_table = np.zeros((size * size * 2, 5))
alpha = 0.1
gamma = 0.6
epsilon = 0.2

episod = 100
for i in range(0, episod):
    progress(i, episod)
    state = env.reset()
    done = False
    eps = 1 - (i + 1) / episod
    while not done:
        action = env.action_space.sample() if np.random.uniform(0, 1) < eps else np.argmax(q_table[state])
        next_state, reward, done = env.step(action) 
        old_value = q_table[state, action]
        next_max = np.max(q_table[next_state])
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state, action] = new_value
        state = next_state
# Out:
# Epoch 99/99: |---------------------------------------------------------------------------------------------------|

# %%
from time import sleep


state = env.reset()
env.render()
sleep(1)

done = False
while not done:
    action = np.argmax(q_table[state])
    state, reward, done = env.step(action)
    env.render()
    sleep(0.5)
# Out:
# <style type="text/css">
# #T_4a9f2_row0_col0 {
#   color: blue;
# }
# #T_4a9f2_row0_col1, #T_4a9f2_row0_col2, #T_4a9f2_row0_col4, #T_4a9f2_row0_col7, #T_4a9f2_row0_col8, #T_4a9f2_row1_col3, #T_4a9f2_row1_col5, #T_4a9f2_row1_col8, #T_4a9f2_row2_col0, #T_4a9f2_row2_col4, #T_4a9f2_row2_col5, #T_4a9f2_row2_col7, #T_4a9f2_row2_col8, #T_4a9f2_row2_col9, #T_4a9f2_row3_col1, #T_4a9f2_row3_col7, #T_4a9f2_row4_col1, #T_4a9f2_row4_col5, #T_4a9f2_row4_col6, #T_4a9f2_row4_col9, #T_4a9f2_row5_col1, #T_4a9f2_row5_col3, #T_4a9f2_row5_col9, #T_4a9f2_row6_col2, #T_4a9f2_row6_col6, #T_4a9f2_row6_col8, #T_4a9f2_row7_col1, #T_4a9f2_row7_col2, #T_4a9f2_row7_col3, #T_4a9f2_row7_col6, #T_4a9f2_row7_col7, #T_4a9f2_row7_col8, #T_4a9f2_row8_col0, #T_4a9f2_row8_col6, #T_4a9f2_row8_col8, #T_4a9f2_row8_col9, #T_4a9f2_row9_col1, #T_4a9f2_row9_col4, #T_4a9f2_row9_col5, #T_4a9f2_row9_col7 {
#   color: red;
# }
# #T_4a9f2_row0_col3, #T_4a9f2_row0_col5, #T_4a9f2_row0_col6, #T_4a9f2_row0_col9, #T_4a9f2_row1_col0, #T_4a9f2_row1_col1, #T_4a9f2_row1_col2, #T_4a9f2_row1_col4, #T_4a9f2_row1_col6, #T_4a9f2_row1_col7, #T_4a9f2_row1_col9, #T_4a9f2_row2_col1, #T_4a9f2_row2_col2, #T_4a9f2_row2_col3, #T_4a9f2_row2_col6, #T_4a9f2_row3_col0, #T_4a9f2_row3_col2, #T_4a9f2_row3_col3, #T_4a9f2_row3_col4, #T_4a9f2_row3_col5, #T_4a9f2_row3_col6, #T_4a9f2_row3_col8, #T_4a9f2_row3_col9, #T_4a9f2_row4_col0, #T_4a9f2_row4_col2, #T_4a9f2_row4_col3, #T_4a9f2_row4_col4, #T_4a9f2_row4_col8, #T_4a9f2_row5_col0, #T_4a9f2_row5_col2, #T_4a9f2_row5_col4, #T_4a9f2_row5_col5, #T_4a9f2_row5_col6, #T_4a9f2_row5_col7, #T_4a9f2_row5_col8, #T_4a9f2_row6_col0, #T_4a9f2_row6_col1, #T_4a9f2_row6_col3, #T_4a9f2_row6_col4, #T_4a9f2_row6_col5, #T_4a9f2_row6_col7, #T_4a9f2_row6_col9, #T_4a9f2_row7_col0, #T_4a9f2_row7_col4, #T_4a9f2_row7_col5, #T_4a9f2_row7_col9, #T_4a9f2_row8_col1, #T_4a9f2_row8_col2, #T_4a9f2_row8_col3, #T_4a9f2_row8_col4, #T_4a9f2_row8_col5, #T_4a9f2_row8_col7, #T_4a9f2_row9_col0, #T_4a9f2_row9_col2, #T_4a9f2_row9_col3, #T_4a9f2_row9_col8, #T_4a9f2_row9_col9 {
#   color: white;
# }
# #T_4a9f2_row4_col7, #T_4a9f2_row9_col6 {
#   color: green;
# }
# </style>
# <table id="T_4a9f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a9f2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4a9f2_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4a9f2_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_4a9f2_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_4a9f2_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_4a9f2_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_4a9f2_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_4a9f2_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_4a9f2_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_4a9f2_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a9f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a9f2_row0_col0" class="data row0 col0" >T</td>
#       <td id="T_4a9f2_row0_col1" class="data row0 col1" >X</td>
#       <td id="T_4a9f2_row0_col2" class="data row0 col2" >X</td>
#       <td id="T_4a9f2_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_4a9f2_row0_col4" class="data row0 col4" >X</td>
#       <td id="T_4a9f2_row0_col5" class="data row0 col5" >.</td>
#       <td id="T_4a9f2_row0_col6" class="data row0 col6" >.</td>
#       <td id="T_4a9f2_row0_col7" class="data row0 col7" >X</td>
#       <td id="T_4a9f2_row0_col8" class="data row0 col8" >X</td>
#       <td id="T_4a9f2_row0_col9" class="data row0 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_4a9f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a9f2_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_4a9f2_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_4a9f2_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_4a9f2_row1_col3" class="data row1 col3" >X</td>
#       <td id="T_4a9f2_row1_col4" class="data row1 col4" >.</td>
#       <td id="T_4a9f2_row1_col5" class="data row1 col5" >X</td>
#       <td id="T_4a9f2_row1_col6" class="data row1 col6" >.</td>
#       <td id="T_4a9f2_row1_col7" class="data row1 col7" >.</td>
#       <td id="T_4a9f2_row1_col8" class="data row1 col8" >X</td>
#       <td id="T_4a9f2_row1_col9" class="data row1 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_4a9f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a9f2_row2_col0" class="data row2 col0" >X</td>
#       <td id="T_4a9f2_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_4a9f2_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_4a9f2_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_4a9f2_row2_col4" class="data row2 col4" >X</td>
#       <td id="T_4a9f2_row2_col5" class="data row2 col5" >X</td>
#       <td id="T_4a9f2_row2_col6" class="data row2 col6" >.</td>
#       <td id="T_4a9f2_row2_col7" class="data row2 col7" >X</td>
#       <td id="T_4a9f2_row2_col8" class="data row2 col8" >X</td>
#       <td id="T_4a9f2_row2_col9" class="data row2 col9" >X</td>
#     </tr>
#     <tr>
#       <th id="T_4a9f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a9f2_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_4a9f2_row3_col1" class="data row3 col1" >X</td>
#       <td id="T_4a9f2_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_4a9f2_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_4a9f2_row3_col4" class="data row3 col4" >.</td>
#       <td id="T_4a9f2_row3_col5" class="data row3 col5" >.</td>
#       <td id="T_4a9f2_row3_col6" class="data row3 col6" >.</td>
#       <td id="T_4a9f2_row3_col7" class="data row3 col7" >X</td>
#       <td id="T_4a9f2_row3_col8" class="data row3 col8" >.</td>
#       <td id="T_4a9f2_row3_col9" class="data row3 col9" >.</td>
#     </tr>
#     <tr>
#       <th id="T_4a9f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a9f2_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_4a9f2_row4_col1" class="data row4 col1" >X</td>
#       <td id="T_4a9f2_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_4a9f2_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_4a9f2_row4_col4" class="data row4 col4" >.</td>
#       <td id="T_4a9f2_row4_col5" class="data row4 col5" >X</td>
#       <td id="T_4a9f2_row4_col6" class="data row4 col6" >X</td>
#       <td id="T_4a9f2_row4_col7" class="data row4 col7" >+</td>
#       <td id="T_4a9f2_row4_col8" class="data row4 col8" >.</td>
#       <td id="T_4a9f2_row4_col9" class="data row4 col9" >X</td>
#     </tr>
#     <tr>
#       <th id="T_4a9f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a9f2_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_4a9f2_row5_col1" class="data row5 col1" >X</td>
#       <td id="T_4a9f2_row5_col2" class="data row5 col2" >.</td>
#       <td id="T_4a9f2_row5_col3" class="data row5 col3" >X</td>
#       <td id="T_4a9f2_row5_col4" class="data row5 col4" >.</td>
#       <td id="T_4a9f2_row5_col5" class="data row5 col5" >.</td>
#       <td id="T_4a9f2_row5_col6" class="data row5 col6" >.</td>
#       <td id="T_4a9f2_row5_col7" class="data row5 col7" >.</td>
#       <td id="T_4a9f2_row5_col8" class="data row5 col8" >.</td>
#       <td id="T_4a9f2_row5_col9" class="data row5 col9" >X</td>
#     </tr>
#     <tr>
#       <th id="T_4a9f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a9f2_row6_col0" class="data row6 col0" >.</td>
#       <td id="T_4a9f2_row6_col1" class="data row6 col1" >.</td>
#       <td id="T_4a9f2_row6_col2" class="data row6 col2" >X</td>
#       <td id="T_4a9f2_row6_col3" class="data row6 col3" >.</td>
#       <td id="T_4a9f2_row6_col4" class="data row6 col4" >.</td>
#       <td id="T_4a9f2_row6_col5" class="data row6 col5" >.</td>
#       <td id="T_4a9f2_row6_col6" class="data row6 col6" >X</td>
#       <td id="T_4a9f2_row6_col7" class="data row6 col7" >.</td>
#       <td id="T_4a9f2_row6_co
